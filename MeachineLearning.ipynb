# %% [markdown]
# <a href="https://colab.research.google.com/github/sammy70707/Portfolio/blob/main/MeachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification

# Generating synthetic data
X, Y = make_classification(n_samples=100, n_features=20, random_state=42)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.30, random_state=42,
    stratify=Y
)

print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"Y_train shape: {Y_train.shape}")
print(f"Y_test shape: {Y_test.shape}")
# Out:
# X_train shape: (70, 20)
# X_test shape: (30, 20)
# Y_train shape: (70,)
# Y_test shape: (30,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report


model = LogisticRegression(random_state=42, solver='liblinear')
model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

confusion_mat = confusion_matrix(y_true=Y_test, y_pred=Y_pred)
clasification_report_str = classification_report(y_true=Y_test, y_pred=Y_pred)

print("Classification Report:")
print(clasification_report_str)
print("\nConfusion Matrix:")
print(confusion_mat)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        15
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Confusion Matrix:
# [[15  0]
#  [ 0 15]]

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gnb = GaussianNB()
gnb.fit(X_train, Y_train)

Y_pred = gnb.predict(X_test)
accuracy = accuracy_score(y_true=Y_test, y_pred=Y_pred)

print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.9

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, Y_train)

Y_pred_rf = rf_model.predict(X_test)

accuracy_rf = accuracy_score(y_true=Y_test, y_pred=Y_pred_rf)

print(f"Random Forest Accuracy: {accuracy_rf}")

print("\nRandom Forest Classification Report:")
print(classification_report(y_true=Y_test, y_pred=Y_pred_rf))
print("\nRandom Forest Confusion Matrix:")
print(confusion_matrix(y_true=Y_test, y_pred=Y_pred_rf))
# Out:
# Random Forest Accuracy: 0.8666666666666667
#
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.80      0.86        15
#            1       0.82      0.93      0.88        15
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30
#
#
# Random Forest Confusion Matrix:
# [[12  3]
#  [ 1 14]]
